# %%
# ROBOTICS assignment 2022-2023, PG Applied AI
# Suggesting interesting walks

# FRANK VAN GAAL, student number 202206412

# %%
import random
import numpy as np
import osmnx as ox
import networkx as nx
import gymnasium as gym
import stable_baselines3 as sb3

# needed to capture user input

import os
import keyboard

# %%
class MyEnv(gym.Env):

    
    def __init__(self):
        super().__init__()

        self.USER_RATING = False    # set to True when user has to rate walks for additional reward, otherwise False
        self.USER_INFO = True       # set to True when user wants to see walks (nodes) and obs features
        
        self.MIN_WALK_DIST = 417    # distance in meters
        self.MAX_WALK_DIST = 4167   # distance in meters
        
        self.MIN_WALK_TIME = self.MIN_WALK_DIST / 1000 * 1/5 * 60   # time in minutes v=5km/h
        self.MAX_WALK_TIME = self.MAX_WALK_DIST / 1000 * 1/5 * 60   # time in minutes v=5km/h

        # action space       
        
        self.action_space = gym.spaces.Discrete(3)
        
        # observation space
        
        self.observation_space = gym.spaces.Box(low=float('-inf'), high=float('Inf'), shape=(8,),
                                                dtype=np.float32)

        # location
        
        self.location = "Onafhankelijkheidsstraat 42, Edegem"
        
        # graph of walkable pathways in 500 m distance, dist can be made larger
        
        graph = ox.graph_from_address(self.location, dist=500, network_type='walk')

        # projected graph (includes coordinate system & measures)
        
        self.G = ox.project_graph(graph)

        # starting point of the walk (node)
        
        self.starting_point = 36242661
        
        # candidate nodes = all nodes from the graph
        
        self.candidate_nodes = list(self.G.nodes)
        
        # interesting nodes = nodes according to amenities (cafe, bar, restaurant, pub, library) 
        # these nodes are collected in advance using a seperate python script using osmnx
        # option 1: within a distance of 30 m of a walking node
        
        self.candidate_inodes = [30349181, 436368334, 295899939, 450940987, 36242668, 36508334, 451908623, 5128521073, 36508336,
                                 451914645, 8534199865, 81026594, 2572086168, 451915681, 451915858, 8489963209, 8534199864]
        
        # interesting nodes = nodes according to amenities 
        # option 2: within a distance of 50 m
        
        # [2572086150, 180170248, 7520932877, 451908623, 34094868, 451914645, 2572086168, 180168857, 2572086176, 451915681,
        # 81026594, 295899939, 8534199847, 450940973, 36508334, 8534199853, 36508336, 8534199858, 7524270519, 8534199864, 
        # 8534199865, 8534199866, 450940987, 5206243901, 5128546494, 451915971, 8489963209, 8489995722, 295899723, 8489963212, 
        # 436368334, 8489963214, 451915858, 451914977, 5128548962, 5128548963, 5128548965, 1592630249, 451914987, 36242668, 
        # 36242669, 5128521073, 30349180, 30349181, 451917438]
        
        # delete inodes from nodes resulting in a seperate list with nodes and a list with inodes without overlap
        
        self.candidate_nodes = list(set(self.candidate_nodes) - set(self.candidate_inodes))
        
        # log of actions to monitor, not part of the obs space
        
        self.log_actions = []        
        
    def current_state(self):
        # Based on the concept of a 'pure' MDP: agent can only see the current state!
        # This means there are no features in the obs that rely on previous states
        
        # dist = current walking distance of walk at state (m or min)
        # diff = difference from desired distance (m or min)
        # n_nodes = number of nodes of walk at state (#)
        # avg_dist = dist / n_nodes (m or min) 
        # n_inodes = number of interesting nodes (#)
        # avg_dist_inodes = (m or min)
        # ratio_inodes (%) = number of inodes w.r.t. number of candidate inodes
        # ratio_inodes_nodes (%) = number of inodes w.r.t. the total number of nodes in the walk
        
        if len(self.current_loop) > 1:
            
            # make route starting from first node to last node and close by returning from last node to first node
            
            self.route = []
            for point in range(0, len(self.current_loop) - 1):
                if len(self.route) > 0:
                    del self.route[-1]
                self.route += nx.shortest_path(self.G, source=self.current_loop[point], target=self.current_loop[point + 1], weight='length')
            if len(self.route) > 0:
                    del self.route[-1]
            self.route += nx.shortest_path(self.G, source=self.current_loop[-1], target=self.current_loop[0], weight='length')
            
            # the distance calculus is based on a loop starting at the first node and ending at the first node
            # the distance is obtained by a custom method (not with nx loop function)
            # taking shortest distances from node to node and closing at the end by returning to the first node
            
            self.dist = 0.0
            for point in range(0, len(self.current_loop) - 1):
                self.dist += nx.shortest_path_length(self.G, self.current_loop[point], self.current_loop[point + 1], weight='length')
            self.dist += nx.shortest_path_length(self.G, self.current_loop[-1], self.current_loop[0], weight='length')
            
            # when working with time goal, the distance is time based
            
            self.dist = self.dist / 1000 * 1/5 * 60
            
            self.diff = self.dist - self.desired_distance
            self.n_nodes = len(self.current_loop)
            
            if self.n_nodes > 0:
                self.avg_dist = self.dist / self.n_nodes
            else:
                self.avg_dist = 0.0
            
            # number of selected interesting nodes = length of the intersection 
            # of the current_loop and the candidate interesting nodes
            
            self.n_inodes = len(list(set(self.candidate_inodes).intersection(set(self.current_loop))))
            
            # other obs, these are ratio's so we must take care of 0 values
            
            if self.n_inodes > 0:
                self.avg_dist_inodes = self.dist / self.n_inodes
            else:
                self.avg_dist_inodes = 0.0
            
            if self.n_inodes > 0 and len(self.candidate_inodes) > 0:
                self.ratio_inodes = round(self.n_inodes / len(self.candidate_inodes), 2)
            else:
                self.ratio_inodes = 0.0
            
            if self.n_inodes > 0 and self.n_nodes > 0:
                self.ratio_inodes_nodes = round(self.n_inodes / self.n_nodes, 2)
            else:
                self.ratio_inodes_nodes = 0.0
        else:
            self.route = []
            self.dist = 0.0
            self.diff = 0.0
            self.n_nodes = 0.0
            self.avg_dist = 0.0
            self.n_inodes = 0.0
            self.avg_dist_inodes = 0.0
            self.ratio_inodes = 0.0
            self.ratio_inodes_nodes = 0.0
 
        # filling the obs space for the agent
        # basic version = obs space with 8 float variables or features
        # different options: which features are useful for the agent? (see report)
    
        curr_state = np.zeros(8)
        curr_state[0] = self.dist
        curr_state[1] = self.diff
        curr_state[2] = self.n_nodes
        curr_state[3] = self.avg_dist
        curr_state[4] = self.n_inodes
        curr_state[5] = self.avg_dist_inodes
        curr_state[6] = self.ratio_inodes
        curr_state[7] = self.ratio_inodes_nodes
        return curr_state

    
    def reset(self):

        # desired distance or duration of the walk (meters or minutes)
        # learn different walks
        
        self.desired_distance = random.uniform(self.MIN_WALK_TIME, self.MAX_WALK_TIME)
        
        # route of the current walk, not part of the obs space  
        
        self.route = []
        
        # current walk (list of selected node_ids by agent)
        
        self.current_loop = []
        self.current_loop.append(self.starting_point)

        self.timestep = 0

        self.dist = 0.0
        self.diff = 0.0
        self.n_nodes = 0.0
        self.avg_dist = 0.0
        self.n_inodes = 0.0
        self.avg_dist_inodes = 0.0
        self.ratio_inodes = 0.0
        self.ratio_inodes_nodes = 0.0

        self.reward = 0

        # just for logging, not part of spaces
        
        self.total_reward = 0

        # just for logging, not part of obs space
        
        self.log_actions = []
        
        return self.current_state(), {}

    
    def step(self, action):
        
        # action the choose from by the agent
        
        if action == 0:
            
            # delete the last node, respect starting node
            
            if len(self.current_loop) > 1:
                self.current_loop.remove(self.current_loop[-1])
            
            self.log_actions.append("A0")
        
        if action == 1:
            
            # add a node from candidate nodes (random)
            # option 1: add random node from list
            
            node_to_add = random.choice(self.candidate_nodes)
            self.current_loop.append(node_to_add)
            
            self.log_actions.append("A1")
            
            # option 2: add a random node from a list of neighbour nodes based on the edges. 
            # this can also be implemented as a seperate action. 
            
            # _, edges = ox.graph_to_gdfs(self.G)
            # next_pos_nodes = edges.loc[self.current_loop[-1], slice(None), slice(None)]
            # pos = random.randint(0, len(next_pos_nodes)-1)
            # self.current_loop.append(next_pos_nodes.iloc[pos].name[0])
        
        if action == 2:
            
            # add a node from candidate inodes (random)
            
            node_to_add = random.choice(self.candidate_inodes)
            self.current_loop.append(node_to_add)
            
            self.log_actions.append("A2")
        
        done = False
        truncated = False
        self.timestep += 1
        if self.timestep >= 250:        # there are +/- 250 nodes to choose from, if after 250 trials no result just truncate
            truncated = True
        else:
                        
            # reward function
            
            reward = 0
            
            # reward for reaching the target desired_distance defined as a range of +/- 1%
            
            cur_dist = self.dist
            min_dist = self.desired_distance * 0.99
            max_dist = self.desired_distance * 1.01
            if min_dist <= cur_dist <= max_dist:
                self.reward = 10
                done = True
                
                # when info is required
                
                if self.USER_INFO:
                    print("************************ NEW WALK MADE! **************************************************")
                    print(f"Desired Dist (min)   : {self.desired_distance}, min: {min_dist}, max: {max_dist}")
                    print(f"Current Dist (min)   : {cur_dist}")
                    print(f"Current Walk (nodes) : {self.current_loop}")
                    print(f"Number of nodes (#)  : {self.n_nodes}")
                    print(f"Number of inodes (#) : {self.n_inodes}")
                    print(f"% used inodes        : {self.ratio_inodes}")
                    print(f"% inodes in walk     : {self.ratio_inodes_nodes}")
                    print(f"Detailed route       : {self.route}")
                    print(f"reward: {env.reward}, total_reward: {self.total_reward}")
                    print(f"Actions by agent     : {self.log_actions}")
                
                # when user wants to rate suggested walks
                
                if self.USER_RATING:
                    ox.plot_graph_route(self.G, self.route)
                    print("Please rate the walk by pressing <a> for reward or other for no reward: ")
                    #os.system("cls")
                    if keyboard.read_key() == 'a':
                        self.reward += 5
                        print("Additional reward!")
                    print("Thx for rating. Agent will continue...")

            else:
                
                # negative reward for planning too long walks
                
                if cur_dist > self.desired_distance:
                    self.reward = -1
                
                # reward for making the walk longer
                
                if cur_dist < self.desired_distance:
                    self.reward = 1
                    
                    # if the last node added is an inode then bonus
                    # to do: using a % and some tresholds to get extra rewards?
                    
                    if self.current_loop[-1] in self.candidate_inodes:
                        self.reward += 1

            self.total_reward += self.reward

        return self.current_state(), self.reward, done, truncated, {}
    
    
    def render(self, mode="human"):
        print("location: ", self.location)
        print("starting point: ", self.starting_point)
        print("candidate nodes", self.candidate_nodes)
        print("length candidate nodes", len(self.candidate_nodes))
        print("candidate inodes", self.candidate_inodes)
        print("length candidate inodes", len(self.candidate_inodes))
        print("====================================================")
        print("desired duration: ", self.desired_distance)
        print("current loop:", self.current_loop)
        print("====================================================")
        print("timestep: ", self.timestep)
        print("current loop:", self.current_loop)
        print("detailed route: ", self.route)
        print("current_state", self.current_state())
        print(f"reward: {env.reward}, total_reward: {self.total_reward}")
        print(f"actions by agent     : {self.log_actions}")
        
        return None

# %%
# TEST THE ENVIRONMENT BEFORE RUNNING AGENT

env = MyEnv()
env.reset()
env.render()
env.step(1)
env.render()
env.step(1)
env.render()
env.step(2)
env.render()
env.step(2)
env.render()
env.step(0)
env.render()
# Out:
# location:  Onafhankelijkheidsstraat 42, Edegem
# starting point:  36242661
# candidate nodes [7520932868, 2797280265, 7520932875, 295899149, 7520932877, 5206248463, 5206248468, 6239396885, 6345026583, 5206248474, 5206248475, 5206248483, 5206248484, 180166695, 450940973, 5206248494, 8622275641, 5206248508, 5206248509, 5206248517, 5206248518, 5206248519, 8622275657, 8622275662, 8622275664, 8622275666, 8622275668, 8622275669, 8622275670, 8622275671, 8622275672, 8622275681, 8622275682, 8622275683, 8622275684, 8622275685, 8622275686, 60056679, 60056680, 8622275689, 8622281920, 8560427115, 8622275691, 8622275693, 8622275694, 8622275695, 8622275692, 8622275696, 8622275697, 8622275698, 8622275699, 8622275700, 8622275702, 8622275703, 8622275704, 8622275705, 8622275701, 8622275706, 8622275707, 8622275708, 8622275710, 8622275709, 8622275711, 8622275712, 8622275714, 8622275713, 8622275715, 8622275716, 5801761933, 5801761936, 180168857, 5206248621, 247277743, 5206248623, 5206248625, 5206248635, 5206248637, 8622281918, 5128546494, 5206248638, 8622281917, 5206248641, 8622281923, 8622281919, 8622281925, 8622281926, 5206248643, 5206248644, 451915973, 451915971, 5221910727, 8622281927, 5206248649, 8622281928, 8622281929, 8622281932, 8622281930, 8622281931, 295900371, 5206248663, 36242651, 5206248668, 36242652, 36242653, 36242654, 36242655, 36242656, 36242657, 36242658, 36242659, 451914977, 36242661, 36242662, 36242667, 36242669, 36242670, 36242671, 36242672, 451914987, 5206248686, 36242675, 5206248684, 36242679, 36242680, 36242682, 1636672770, 8621999373, 10537564431, 8621999375, 8621999376, 10537564432, 10537564433, 5128551738, 5128551739, 800044371, 81042778, 81042779, 81042780, 8948369761, 8821395822, 8560449918, 8622281921, 81042826, 2799356299, 308580750, 5206248857, 5206248858, 5206248859, 1812234652, 8706816413, 8706816414, 8622281922, 8706816411, 5206248871, 5206248874, 5206248876, 6359910829, 451909038, 6359910833, 7524270519, 450933176, 6359910839, 451917249, 451917250, 8489995722, 8622281924, 8489995729, 8489995739, 8622275687, 8622275688, 451916271, 8622275690, 8573220357, 8573220359, 180170248, 8534199840, 8534199841, 295900706, 8534199847, 8534199853, 8534199858, 8534199866, 8534199867, 5206243901, 8534199871, 8534199872, 8534199878, 8534199881, 36508234, 295899723, 8534199887, 8534199896, 8534199897, 8534199898, 8534199899, 6328539741, 10684421726, 10684421728, 5128548962, 5128548963, 10684421730, 5128548965, 8534199909, 10684421732, 10684421733, 6328539753, 4935936618, 4935936619, 4935936620, 10684421736, 5221854835, 10684421747, 10684421748, 10684421750, 10684421749, 451917438, 8489963212, 8489963214, 34564871, 34094859, 34564878, 34564879, 34094868, 34564889, 34564904, 6345028392, 8821350198, 8821350199, 295899959, 8821350200, 8821350201, 34564922, 8821350203, 8821350205, 8821350202, 34564928, 8821350210, 295899971, 34094932, 2572086139, 30349180, 2572086142, 30349183, 30349184, 2572086150, 2572086154, 2572086156, 2572086176, 2572086183, 2572086185, 2572086187, 2572086191, 81042360, 34095041, 436368333, 450932687, 5128552424, 1592630249, 5128552425, 308580335]
# length candidate nodes 260
# candidate inodes [30349181, 436368334, 295899939, 450940987, 36242668, 36508334, 451908623, 5128521073, 36508336, 451914645, 8534199865, 81026594, 2572086168, 451915681, 451915858, 8489963209, 8534199864]
# length candidate inodes 17
# ====================================================
# desired duration:  17.89628461519854
# current loop: [36242661]
# ====================================================
# timestep:  0
# current loop: [36242661]
# detailed route:  []
# current_state [0. 0. 0. 0. 0. 0. 0. 0.]
# reward: 0, total_reward: 0
# actions by agent     : []
# location:  Onafhankelijkheidsstraat 42, Edegem
# starting point:  36242661
# candidate nodes [7520932868, 2797280265, 7520932875, 295899149, 7520932877, 5206248463, 5206248468, 6239396885, 6345026583, 5206248474, 5206248475, 5206248483, 5206248484, 180166695, 450940973, 5206248494, 8622275641, 5206248508, 5206248509, 5206248517, 5206248518, 5206248519, 8622275657, 8622275662, 8622275664, 8622275666, 8622275668, 8622275669, 8622275670, 8622275671, 8622275672, 8622275681, 8622275682, 8622275683, 8622275684, 8622275685, 8622275686, 60056679, 60056680, 8622275689, 8622281920, 8560427115, 8622275691, 8622275693, 8622275694, 8622275695, 8622275692, 8622275696, 8622275697, 8622275698, 8622275699, 8622275700, 8622275702, 8622275703, 8622275704, 8622275705, 8622275701, 8622275706, 8622275707, 8622275708, 8622275710, 8622275709, 8622275711, 8622275712, 8622275714, 8622275713, 8622275715, 8622275716, 5801761933, 5801761936, 180168857, 5206248621, 247277743, 5206248623, 5206248625, 5206248635, 5206248637, 8622281918, 5128546494, 5206248638, 8622281917, 5206248641, 8622281923, 8622281919, 8622281925, 8622281926, 5206248643, 5206248644, 451915973, 451915971, 5221910727, 8622281927, 5206248649, 8622281928, 8622281929, 8622281932, 8622281930, 8622281931, 295900371, 5206248663, 36242651, 5206248668, 36242652, 36242653, 36242654, 36242655, 36242656, 36242657, 36242658, 36242659, 451914977, 36242661, 36242662, 36242667, 36242669, 36242670, 36242671, 36242672, 451914987, 5206248686, 36242675, 5206248684, 36242679, 36242680, 36242682, 1636672770, 8621999373, 10537564431, 8621999375, 8621999376, 10537564432, 10537564433, 5128551738, 5128551739, 800044371, 81042778, 81042779, 81042780, 8948369761, 8821395822, 8560449918, 8622281921, 81042826, 2799356299, 308580750, 5206248857, 5206248858, 5206248859, 1812234652, 8706816413, 8706816414, 8622281922, 8706816411, 5206248871, 5206248874, 5206248876, 6359910829, 451909038, 6359910833, 7524270519, 450933176, 6359910839, 451917249, 451917250, 8489995722, 8622281924, 8489995729, 8489995739, 8622275687, 8622275688, 451916271, 8622275690, 8573220357, 8573220359, 180170248, 8534199840, 8534199841, 295900706, 8534199847, 8534199853, 8534199858, 8534199866, 8534199867, 5206243901, 8534199871, 8534199872, 8534199878, 8534199881, 36508234, 295899723, 8534199887, 8534199896, 8534199897, 8534199898, 8534199899, 6328539741, 10684421726, 10684421728, 5128548962, 5128548963, 10684421730, 5128548965, 8534199909, 10684421732, 10684421733, 6328539753, 4935936618, 4935936619, 4935936620, 10684421736, 5221854835, 10684421747, 10684421748, 10684421750, 10684421749, 451917438, 8489963212, 8489963214, 34564871, 34094859, 34564878, 34564879, 34094868, 34564889, 34564904, 6345028392, 8821350198, 8821350199, 295899959, 8821350200, 8821350201, 34564922, 8821350203, 8821350205, 8821350202, 34564928, 8821350210, 295899971, 34094932, 2572086139, 30349180, 2572086142, 30349183, 30349184, 2572086150, 2572086154, 2572086156, 2572086176, 2572086183, 2572086185, 2572086187, 2572086191, 81042360, 34095041, 436368333, 450932687, 5128552424, 1592630249, 5128552425, 308580335]
# length candidate nodes 260
# candidate inodes [30349181, 436368334, 295899939, 450940987, 36242668, 36508334, 451908623, 5128521073, 36508336, 451914645, 8534199865, 81026594, 2572086168, 451915681, 451915858, 8489963209, 8534199864]
# length candidate inodes 17
# ====================================================
# desired duration:  17.89628461519854
# current loop: [36242661, 8622275700]
# ====================================================
# timestep:  1
# current loop: [36242661, 8622275700]
# detailed route:  [36242661, 60056680, 36242662, 36242682, 36242679, 36242680, 8622275662, 8621999376, 8622275657, 8622275691, 8622275692, 8622275694, 8622275697, 8622275700, 8622275697, 8622275694, 8622275692, 8622275691, 8622275657, 8621999376, 8622275662, 36242680, 36242679, 36242682, 36242662, 60056680, 36242661]
# current_state [ 8.491584   -9.40470062  2.          4.245792    0.          0.
#   0.          0.        ]
# reward: 1, total_reward: 1
# actions by agent     : ['A1']
# location:  Onafhankelijkheidsstraat 42, Edegem
# starting point:  36242661
# candidate nodes [7520932868, 2797280265, 7520932875, 295899149, 7520932877, 5206248463, 5206248468, 6239396885, 6345026583, 5206248474, 5206248475, 5206248483, 5206248484, 180166695, 450940973, 5206248494, 8622275641, 5206248508, 5206248509, 5206248517, 5206248518, 5206248519, 8622275657, 8622275662, 8622275664, 8622275666, 8622275668, 8622275669, 8622275670, 8622275671, 8622275672, 8622275681, 8622275682, 8622275683, 8622275684, 8622275685, 8622275686, 60056679, 60056680, 8622275689, 8622281920, 8560427115, 8622275691, 8622275693, 8622275694, 8622275695, 8622275692, 8622275696, 8622275697, 8622275698, 8622275699, 8622275700, 8622275702, 8622275703, 8622275704, 8622275705, 8622275701, 8622275706, 8622275707, 8622275708, 8622275710, 8622275709, 8622275711, 8622275712, 8622275714, 8622275713, 8622275715, 8622275716, 5801761933, 5801761936, 180168857, 5206248621, 247277743, 5206248623, 5206248625, 5206248635, 5206248637, 8622281918, 5128546494, 5206248638, 8622281917, 5206248641, 8622281923, 8622281919, 8622281925, 8622281926, 5206248643, 5206248644, 451915973, 451915971, 5221910727, 8622281927, 5206248649, 8622281928, 8622281929, 8622281932, 8622281930, 8622281931, 295900371, 5206248663, 36242651, 5206248668, 36242652, 36242653, 36242654, 36242655, 36242656, 36242657, 36242658, 36242659, 451914977, 36242661, 36242662, 36242667, 36242669, 36242670, 36242671, 36242672, 451914987, 5206248686, 36242675, 5206248684, 36242679, 36242680, 36242682, 1636672770, 8621999373, 10537564431, 8621999375, 8621999376, 10537564432, 10537564433, 5128551738, 5128551739, 800044371, 81042778, 81042779, 81042780, 8948369761, 8821395822, 8560449918, 8622281921, 81042826, 2799356299, 308580750, 5206248857, 5206248858, 5206248859, 1812234652, 8706816413, 8706816414, 8622281922, 8706816411, 5206248871, 5206248874, 5206248876, 6359910829, 451909038, 6359910833, 7524270519, 450933176, 6359910839, 451917249, 451917250, 8489995722, 8622281924, 8489995729, 8489995739, 8622275687, 8622275688, 451916271, 8622275690, 8573220357, 8573220359, 180170248, 8534199840, 8534199841, 295900706, 8534199847, 8534199853, 8534199858, 8534199866, 8534199867, 5206243901, 8534199871, 8534199872, 8534199878, 8534199881, 36508234, 295899723, 8534199887, 8534199896, 8534199897, 8534199898, 8534199899, 6328539741, 10684421726, 10684421728, 5128548962, 5128548963, 10684421730, 5128548965, 8534199909, 10684421732, 10684421733, 6328539753, 4935936618, 4935936619, 4935936620, 10684421736, 5221854835, 10684421747, 10684421748, 10684421750, 10684421749, 451917438, 8489963212, 8489963214, 34564871, 34094859, 34564878, 34564879, 34094868, 34564889, 34564904, 6345028392, 8821350198, 8821350199, 295899959, 8821350200, 8821350201, 34564922, 8821350203, 8821350205, 8821350202, 34564928, 8821350210, 295899971, 34094932, 2572086139, 30349180, 2572086142, 30349183, 30349184, 2572086150, 2572086154, 2572086156, 2572086176, 2572086183, 2572086185, 2572086187, 2572086191, 81042360, 34095041, 436368333, 450932687, 5128552424, 1592630249, 5128552425, 308580335]
# length candidate nodes 260
# candidate inodes [30349181, 436368334, 295899939, 450940987, 36242668, 36508334, 451908623, 5128521073, 36508336, 451914645, 8534199865, 81026594, 2572086168, 451915681, 451915858, 8489963209, 8534199864]
# length candidate inodes 17
# ====================================================
# desired duration:  17.89628461519854
# current loop: [36242661, 8622275700, 8622281925]
# ====================================================
# timestep:  2
# current loop: [36242661, 8622275700, 8622281925]
# detailed route:  [36242661, 60056680, 36242662, 36242682, 36242679, 36242680, 8622275662, 8621999376, 8622275657, 8622275691, 8622275692, 8622275694, 8622275697, 8622275700, 8622275707, 8622275704, 8622275710, 8622275666, 8622281924, 8622281930, 8622281925, 8622275714, 8622281929, 8622275712, 8622275709, 8622275703, 8622275706, 8622275699, 8622275696, 8622275692, 8622275691, 8622275657, 8621999376, 8622275662, 36242680, 36242679, 36242682, 36242662, 60056680, 36242661]
# current_state [10.359444   -7.53684062  3.          3.453148    0.          0.
#   0.          0.        ]
# reward: 1, total_reward: 2
# actions by agent     : ['A1', 'A1']
# location:  Onafhankelijkheidsstraat 42, Edegem
# starting point:  36242661
# candidate nodes [7520932868, 2797280265, 7520932875, 295899149, 7520932877, 5206248463, 5206248468, 6239396885, 6345026583, 5206248474, 5206248475, 5206248483, 5206248484, 180166695, 450940973, 5206248494, 8622275641, 5206248508, 5206248509, 5206248517, 5206248518, 5206248519, 8622275657, 8622275662, 8622275664, 8622275666, 8622275668, 8622275669, 8622275670, 8622275671, 8622275672, 8622275681, 8622275682, 8622275683, 8622275684, 8622275685, 8622275686, 60056679, 60056680, 8622275689, 8622281920, 8560427115, 8622275691, 8622275693, 8622275694, 8622275695, 8622275692, 8622275696, 8622275697, 8622275698, 8622275699, 8622275700, 8622275702, 8622275703, 8622275704, 8622275705, 8622275701, 8622275706, 8622275707, 8622275708, 8622275710, 8622275709, 8622275711, 8622275712, 8622275714, 8622275713, 8622275715, 8622275716, 5801761933, 5801761936, 180168857, 5206248621, 247277743, 5206248623, 5206248625, 5206248635, 5206248637, 8622281918, 5128546494, 5206248638, 8622281917, 5206248641, 8622281923, 8622281919, 8622281925, 8622281926, 5206248643, 5206248644, 451915973, 451915971, 5221910727, 8622281927, 5206248649, 8622281928, 8622281929, 8622281932, 8622281930, 8622281931, 295900371, 5206248663, 36242651, 5206248668, 36242652, 36242653, 36242654, 36242655, 36242656, 36242657, 36242658, 36242659, 451914977, 36242661, 36242662, 36242667, 36242669, 36242670, 36242671, 36242672, 451914987, 5206248686, 36242675, 5206248684, 36242679, 36242680, 36242682, 1636672770, 8621999373, 10537564431, 8621999375, 8621999376, 10537564432, 10537564433, 5128551738, 5128551739, 800044371, 81042778, 81042779, 81042780, 8948369761, 8821395822, 8560449918, 8622281921, 81042826, 2799356299, 308580750, 5206248857, 5206248858, 5206248859, 1812234652, 8706816413, 8706816414, 8622281922, 8706816411, 5206248871, 5206248874, 5206248876, 6359910829, 451909038, 6359910833, 7524270519, 450933176, 6359910839, 451917249, 451917250, 8489995722, 8622281924, 8489995729, 8489995739, 8622275687, 8622275688, 451916271, 8622275690, 8573220357, 8573220359, 180170248, 8534199840, 8534199841, 295900706, 8534199847, 8534199853, 8534199858, 8534199866, 8534199867, 5206243901, 8534199871, 8534199872, 8534199878, 8534199881, 36508234, 295899723, 8534199887, 8534199896, 8534199897, 8534199898, 8534199899, 6328539741, 10684421726, 10684421728, 5128548962, 5128548963, 10684421730, 5128548965, 8534199909, 10684421732, 10684421733, 6328539753, 4935936618, 4935936619, 4935936620, 10684421736, 5221854835, 10684421747, 10684421748, 10684421750, 10684421749, 451917438, 8489963212, 8489963214, 34564871, 34094859, 34564878, 34564879, 34094868, 34564889, 34564904, 6345028392, 8821350198, 8821350199, 295899959, 8821350200, 8821350201, 34564922, 8821350203, 8821350205, 8821350202, 34564928, 8821350210, 295899971, 34094932, 2572086139, 30349180, 2572086142, 30349183, 30349184, 2572086150, 2572086154, 2572086156, 2572086176, 2572086183, 2572086185, 2572086187, 2572086191, 81042360, 34095041, 436368333, 450932687, 5128552424, 1592630249, 5128552425, 308580335]
# length candidate nodes 260
# candidate inodes [30349181, 436368334, 295899939, 450940987, 36242668, 36508334, 451908623, 5128521073, 36508336, 451914645, 8534199865, 81026594, 2572086168, 451915681, 451915858, 8489963209, 8534199864]
# length candidate inodes 17
# ====================================================
# desired duration:  17.89628461519854
# current loop: [36242661, 8622275700, 8622281925, 5128521073]
# ====================================================
# timestep:  3
# current loop: [36242661, 8622275700, 8622281925, 5128521073]
# detailed route:  [36242661, 60056680, 36242662, 36242682, 36242679, 36242680, 8622275662, 8621999376, 8622275657, 8622275691, 8622275692, 8622275694, 8622275697, 8622275700, 8622275707, 8622275704, 8622275710, 8622275666, 8622281924, 8622281930, 8622281925, 8622275714, 8622281929, 8622275712, 8622275709, 8622275703, 8622275706, 8622275699, 8622275696, 8622275692, 8622275691, 8622275657, 8621999376, 8622275662, 36242680, 36242679, 36242682, 36242662, 60056679, 36242667, 36242669, 36242668, 36508334, 5128521073, 36508334, 36242668, 36242669, 295900371, 36242661]
# current_state [16.326696   -1.56958862  4.          4.081674    1.         16.326696
#   0.06        0.25      ]
# reward: 2, total_reward: 4
# actions by agent     : ['A1', 'A1', 'A2']
# location:  Onafhankelijkheidsstraat 42, Edegem
# starting point:  36242661
# candidate nodes [7520932868, 2797280265, 7520932875, 295899149, 7520932877, 5206248463, 5206248468, 6239396885, 6345026583, 5206248474, 5206248475, 5206248483, 5206248484, 180166695, 450940973, 5206248494, 8622275641, 5206248508, 5206248509, 5206248517, 5206248518, 5206248519, 8622275657, 8622275662, 8622275664, 8622275666, 8622275668, 8622275669, 8622275670, 8622275671, 8622275672, 8622275681, 8622275682, 8622275683, 8622275684, 8622275685, 8622275686, 60056679, 60056680, 8622275689, 8622281920, 8560427115, 8622275691, 8622275693, 8622275694, 8622275695, 8622275692, 8622275696, 8622275697, 8622275698, 8622275699, 8622275700, 8622275702, 8622275703, 8622275704, 8622275705, 8622275701, 8622275706, 8622275707, 8622275708, 8622275710, 8622275709, 8622275711, 8622275712, 8622275714, 8622275713, 8622275715, 8622275716, 5801761933, 5801761936, 180168857, 5206248621, 247277743, 5206248623, 5206248625, 5206248635, 5206248637, 8622281918, 5128546494, 5206248638, 8622281917, 5206248641, 8622281923, 8622281919, 8622281925, 8622281926, 5206248643, 5206248644, 451915973, 451915971, 5221910727, 8622281927, 5206248649, 8622281928, 8622281929, 8622281932, 8622281930, 8622281931, 295900371, 5206248663, 36242651, 5206248668, 36242652, 36242653, 36242654, 36242655, 36242656, 36242657, 36242658, 36242659, 451914977, 36242661, 36242662, 36242667, 36242669, 36242670, 36242671, 36242672, 451914987, 5206248686, 36242675, 5206248684, 36242679, 36242680, 36242682, 1636672770, 8621999373, 10537564431, 8621999375, 8621999376, 10537564432, 10537564433, 5128551738, 5128551739, 800044371, 81042778, 81042779, 81042780, 8948369761, 8821395822, 8560449918, 8622281921, 81042826, 2799356299, 308580750, 5206248857, 5206248858, 5206248859, 1812234652, 8706816413, 8706816414, 8622281922, 8706816411, 5206248871, 5206248874, 5206248876, 6359910829, 451909038, 6359910833, 7524270519, 450933176, 6359910839, 451917249, 451917250, 8489995722, 8622281924, 8489995729, 8489995739, 8622275687, 8622275688, 451916271, 8622275690, 8573220357, 8573220359, 180170248, 8534199840, 8534199841, 295900706, 8534199847, 8534199853, 8534199858, 8534199866, 8534199867, 5206243901, 8534199871, 8534199872, 8534199878, 8534199881, 36508234, 295899723, 8534199887, 8534199896, 8534199897, 8534199898, 8534199899, 6328539741, 10684421726, 10684421728, 5128548962, 5128548963, 10684421730, 5128548965, 8534199909, 10684421732, 10684421733, 6328539753, 4935936618, 4935936619, 4935936620, 10684421736, 5221854835, 10684421747, 10684421748, 10684421750, 10684421749, 451917438, 8489963212, 8489963214, 34564871, 34094859, 34564878, 34564879, 34094868, 34564889, 34564904, 6345028392, 8821350198, 8821350199, 295899959, 8821350200, 8821350201, 34564922, 8821350203, 8821350205, 8821350202, 34564928, 8821350210, 295899971, 34094932, 2572086139, 30349180, 2572086142, 30349183, 30349184, 2572086150, 2572086154, 2572086156, 2572086176, 2572086183, 2572086185, 2572086187, 2572086191, 81042360, 34095041, 436368333, 450932687, 5128552424, 1592630249, 5128552425, 308580335]
# length candidate nodes 260
# candidate inodes [30349181, 436368334, 295899939, 450940987, 36242668, 36508334, 451908623, 5128521073, 36508336, 451914645, 8534199865, 81026594, 2572086168, 451915681, 451915858, 8489963209, 8534199864]
# length candidate inodes 17
# ====================================================
# desired duration:  17.89628461519854
# current loop: [36242661, 8622275700, 8622281925, 5128521073, 36242668]
# ====================================================
# timestep:  4
# current loop: [36242661, 8622275700, 8622281925, 5128521073, 36242668]
# detailed route:  [36242661, 60056680, 36242662, 36242682, 36242679, 36242680, 8622275662, 8621999376, 8622275657, 8622275691, 8622275692, 8622275694, 8622275697, 8622275700, 8622275707, 8622275704, 8622275710, 8622275666, 8622281924, 8622281930, 8622281925, 8622275714, 8622281929, 8622275712, 8622275709, 8622275703, 8622275706, 8622275699, 8622275696, 8622275692, 8622275691, 8622275657, 8621999376, 8622275662, 36242680, 36242679, 36242682, 36242662, 60056679, 36242667, 36242669, 36242668, 36508334, 5128521073, 36508334, 36242668, 36242669, 295900371, 36242661]
# current_state [16.326696   -1.56958862  5.          3.2653392   2.          8.163348
#   0.12        0.4       ]
# reward: 2, total_reward: 6
# actions by agent     : ['A1', 'A1', 'A2', 'A2']
# location:  Onafhankelijkheidsstraat 42, Edegem
# starting point:  36242661
# candidate nodes [7520932868, 2797280265, 7520932875, 295899149, 7520932877, 5206248463, 5206248468, 6239396885, 6345026583, 5206248474, 5206248475, 5206248483, 5206248484, 180166695, 450940973, 5206248494, 8622275641, 5206248508, 5206248509, 5206248517, 5206248518, 5206248519, 8622275657, 8622275662, 8622275664, 8622275666, 8622275668, 8622275669, 8622275670, 8622275671, 8622275672, 8622275681, 8622275682, 8622275683, 8622275684, 8622275685, 8622275686, 60056679, 60056680, 8622275689, 8622281920, 8560427115, 8622275691, 8622275693, 8622275694, 8622275695, 8622275692, 8622275696, 8622275697, 8622275698, 8622275699, 8622275700, 8622275702, 8622275703, 8622275704, 8622275705, 8622275701, 8622275706, 8622275707, 8622275708, 8622275710, 8622275709, 8622275711, 8622275712, 8622275714, 8622275713, 8622275715, 8622275716, 5801761933, 5801761936, 180168857, 5206248621, 247277743, 5206248623, 5206248625, 5206248635, 5206248637, 8622281918, 5128546494, 5206248638, 8622281917, 5206248641, 8622281923, 8622281919, 8622281925, 8622281926, 5206248643, 5206248644, 451915973, 451915971, 5221910727, 8622281927, 5206248649, 8622281928, 8622281929, 8622281932, 8622281930, 8622281931, 295900371, 5206248663, 36242651, 5206248668, 36242652, 36242653, 36242654, 36242655, 36242656, 36242657, 36242658, 36242659, 451914977, 36242661, 36242662, 36242667, 36242669, 36242670, 36242671, 36242672, 451914987, 5206248686, 36242675, 5206248684, 36242679, 36242680, 36242682, 1636672770, 8621999373, 10537564431, 8621999375, 8621999376, 10537564432, 10537564433, 5128551738, 5128551739, 800044371, 81042778, 81042779, 81042780, 8948369761, 8821395822, 8560449918, 8622281921, 81042826, 2799356299, 308580750, 5206248857, 5206248858, 5206248859, 1812234652, 8706816413, 8706816414, 8622281922, 8706816411, 5206248871, 5206248874, 5206248876, 6359910829, 451909038, 6359910833, 7524270519, 450933176, 6359910839, 451917249, 451917250, 8489995722, 8622281924, 8489995729, 8489995739, 8622275687, 8622275688, 451916271, 8622275690, 8573220357, 8573220359, 180170248, 8534199840, 8534199841, 295900706, 8534199847, 8534199853, 8534199858, 8534199866, 8534199867, 5206243901, 8534199871, 8534199872, 8534199878, 8534199881, 36508234, 295899723, 8534199887, 8534199896, 8534199897, 8534199898, 8534199899, 6328539741, 10684421726, 10684421728, 5128548962, 5128548963, 10684421730, 5128548965, 8534199909, 10684421732, 10684421733, 6328539753, 4935936618, 4935936619, 4935936620, 10684421736, 5221854835, 10684421747, 10684421748, 10684421750, 10684421749, 451917438, 8489963212, 8489963214, 34564871, 34094859, 34564878, 34564879, 34094868, 34564889, 34564904, 6345028392, 8821350198, 8821350199, 295899959, 8821350200, 8821350201, 34564922, 8821350203, 8821350205, 8821350202, 34564928, 8821350210, 295899971, 34094932, 2572086139, 30349180, 2572086142, 30349183, 30349184, 2572086150, 2572086154, 2572086156, 2572086176, 2572086183, 2572086185, 2572086187, 2572086191, 81042360, 34095041, 436368333, 450932687, 5128552424, 1592630249, 5128552425, 308580335]
# length candidate nodes 260
# candidate inodes [30349181, 436368334, 295899939, 450940987, 36242668, 36508334, 451908623, 5128521073, 36508336, 451914645, 8534199865, 81026594, 2572086168, 451915681, 451915858, 8489963209, 8534199864]
# length candidate inodes 17
# ====================================================
# desired duration:  17.89628461519854
# current loop: [36242661, 8622275700, 8622281925, 5128521073]
# ====================================================
# timestep:  5
# current loop: [36242661, 8622275700, 8622281925, 5128521073]
# detailed route:  [36242661, 60056680, 36242662, 36242682, 36242679, 36242680, 8622275662, 8621999376, 8622275657, 8622275691, 8622275692, 8622275694, 8622275697, 8622275700, 8622275707, 8622275704, 8622275710, 8622275666, 8622281924, 8622281930, 8622281925, 8622275714, 8622281929, 8622275712, 8622275709, 8622275703, 8622275706, 8622275699, 8622275696, 8622275692, 8622275691, 8622275657, 8621999376, 8622275662, 36242680, 36242679, 36242682, 36242662, 60056679, 36242667, 36242669, 36242668, 36508334, 5128521073, 36508334, 36242668, 36242669, 295900371, 36242661]
# current_state [16.326696   -1.56958862  4.          4.081674    1.         16.326696
#   0.06        0.25      ]
# reward: 2, total_reward: 8
# actions by agent     : ['A1', 'A1', 'A2', 'A2', 'A0']

# %%
# check action space and obs space

print(env.action_space)
print(env.observation_space)
# Out:
# Discrete(3)
# Box(-inf, inf, (8,), float32)

# %%
# RUNNING AGENT
agent = sb3.PPO('MlpPolicy', env=env, tensorboard_log="\LOG", verbose=1)
agent.learn(total_timesteps=60_000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to \LOG\PPO_14
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 34.68449359694337, min: 34.33764866097393, max: 35.031338532912805
# Current Dist (min)   : 34.469376000000004
# Current Walk (nodes) : [36242661, 5128521073, 8622275705, 451915858, 8706816413, 36508334, 36508334]
# Number of nodes (#)  : 8
# Number of inodes (#) : 3
# % used inodes        : 0.18
# % inodes in walk     : 0.38
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 5128521073, 36508334, 36242668, 36242669, 36242667, 60056679, 36242662, 36242682, 36242679, 36242680, 8622275662, 8621999376, 8622275657, 8622275691, 8622275692, 8622275694, 8622275697, 8622275700, 8622275707, 8622275708, 8622275705, 8622275708, 8622275707, 8622275700, 8622275697, 8622275694, 8622275692, 8622275691, 8622275657, 8621999376, 8622275662, 36242680, 36242679, 36242682, 36242662, 60056679, 36242667, 36242669, 36242668, 36508334, 451908623, 451915858, 451915971, 451915973, 451914977, 8560427115, 8560449918, 8534199881, 8534199896, 8534199887, 8534199909, 34564928, 4935936620, 5128551738, 8706816413, 5128551738, 4935936620, 34564928, 8534199909, 8534199887, 8534199896, 8534199881, 8560449918, 8560427115, 451914977, 451915973, 451915971, 451915858, 451908623, 36508334, 451908623, 451915858, 451915971, 451915973, 451909038, 451915973, 451915971, 451915858, 451908623, 36508334, 36242668, 36242669, 295900371, 36242661]
# reward: 10, total_reward: 0
# Actions by agent     : ['A2', 'A1', 'A1', 'A2', 'A1', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A1', 'A0', 'A2', 'A1', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A2', 'A2', 'A2', 'A1', 'A0', 'A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A2', 'A1', 'A0', 'A0', 'A2', 'A1', 'A2', 'A0', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A0', 'A0', 'A0', 'A2', 'A1', 'A2', 'A2', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A2', 'A0', 'A1', 'A2', 'A2', 'A1', 'A0']
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    fps             | 21       |
# |    iterations      | 1        |
# |    time_elapsed    | 96       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 19.73464175074535, min: 19.537295333237896, max: 19.931988168252804
# Current Dist (min)   : 19.85676
# Current Walk (nodes) : [36242661, 8534199864, 34564922, 295899939]
# Number of nodes (#)  : 3
# Number of inodes (#) : 1
# % used inodes        : 0.06
# % inodes in walk     : 0.33
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915681, 451914645, 36508336, 8534199865, 8534199864, 8534199865, 36508336, 295899971, 36508234, 30349180, 5128548965, 5128548962, 30349181, 436368334, 436368333, 34564922, 436368333, 34564878, 10684421728, 10684421726, 10684421750, 36242679, 36242682, 36242662, 60056680, 36242661]
# reward: 10, total_reward: 14
# Actions by agent     : ['A0', 'A2', 'A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A1', 'A2']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 21.24958324227983, min: 21.03708740985703, max: 21.46207907470263
# Current Dist (min)   : 21.405024
# Current Walk (nodes) : [36242661, 451915681, 81026594, 450940987]
# Number of nodes (#)  : 3
# Number of inodes (#) : 2
# % used inodes        : 0.12
# % inodes in walk     : 0.67
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915681, 451908623, 36508334, 450940987, 450940973, 34094859, 6328539753, 36242670, 36242658, 36242657, 180170248, 180168857, 81026594, 180168857, 180170248, 36242657, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 7
# Actions by agent     : ['A2', 'A0', 'A2', 'A2', 'A2']
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 216         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 2           |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009647399 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0602     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0093     |
# |    value_loss           | 78.2        |
# -----------------------------------------
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 26.696173742334423, min: 26.42921200491108, max: 26.963135479757767
# Current Dist (min)   : 26.50446
# Current Walk (nodes) : [36242661, 1592630249, 451914645, 295899939, 451915858]
# Number of nodes (#)  : 6
# Number of inodes (#) : 3
# % used inodes        : 0.18
# % inodes in walk     : 0.5
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915681, 451914645, 36508336, 8534199865, 1592630249, 8534199865, 36508336, 451914645, 36508336, 295899971, 36508234, 30349180, 5128548965, 5128548962, 30349181, 295899939, 30349181, 5128548962, 5128548965, 30349180, 36508234, 295899971, 36508336, 451914645, 451915858, 451915971, 451915973, 451914977, 8560427115, 8560449918, 8534199881, 8534199896, 8534199897, 8534199840, 8534199899, 8534199840, 8534199897, 8534199896, 8534199881, 8560449918, 8560427115, 451914977, 451915973, 451915971, 451915858, 451908623, 36508334, 36242668, 36242669, 295900371, 36242661]
# reward: 10, total_reward: 57
# Actions by agent     : ['A0', 'A1', 'A2', 'A1', 'A0', 'A2', 'A0', 'A0', 'A1', 'A1', 'A2', 'A2', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A1', 'A0', 'A0', 'A1', 'A2', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A2', 'A0', 'A1', 'A2', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A1', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 47.46128148859868, min: 46.98666867371269, max: 47.935894303484666
# Current Dist (min)   : 47.16976799999999
# Current Walk (nodes) : [36242661, 81026594, 10684421748, 451914645, 436368334, 2572086191, 451908623]
# Number of nodes (#)  : 6
# Number of inodes (#) : 3
# % used inodes        : 0.18
# % inodes in walk     : 0.5
# Detailed route       : [36242661, 8573220359, 295900706, 6328539741, 36242659, 36242656, 36242657, 180170248, 180168857, 81026594, 2572086168, 2572086150, 36242655, 36242654, 36242653, 800044371, 8622275668, 8622281917, 8622281921, 8622281918, 8622281928, 8622275702, 8622275641, 8622275662, 36242680, 36242679, 10684421750, 10684421748, 10684421750, 36242679, 36242682, 36242662, 60056679, 36242667, 36242669, 36242668, 36508334, 451908623, 451915681, 451914645, 36508336, 295899971, 36508234, 30349180, 5128548965, 5128548962, 30349181, 436368334, 30349181, 295899939, 60056679, 60056680, 36242661, 8573220359, 295900706, 6328539741, 36242659, 36242658, 308580750, 81042780, 5206248643, 81042779, 81042778, 2572086191, 81042778, 81042779, 5206248643, 81042780, 308580750, 36242658, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 40
# Actions by agent     : ['A2', 'A0', 'A1', 'A0', 'A2', 'A1', 'A1', 'A2', 'A0', 'A0', 'A0', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A2', 'A1', 'A1', 'A0', 'A0', 'A1', 'A2', 'A2', 'A1', 'A0', 'A1', 'A2']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 16.28817412145572, min: 16.125292380241163, max: 16.45105586267028
# Current Dist (min)   : 16.388364000000003
# Current Walk (nodes) : [36242661, 10684421732]
# Number of nodes (#)  : 3
# Number of inodes (#) : 1
# % used inodes        : 0.06
# % inodes in walk     : 0.33
# Detailed route       : [36242661, 60056680, 36242662, 36242682, 36242679, 10684421750, 10684421726, 10684421733, 10684421730, 10684421732, 10684421730, 10684421728, 34564878, 436368333, 436368334, 30349181, 5128548962, 5128548965, 30349180, 36508234, 295899971, 36508336, 8534199865, 8534199864, 8534199865, 36508336, 451914645, 451915681, 451908623, 36508334, 36242668, 36242669, 295900371, 36242661]
# reward: 10, total_reward: 6
# Actions by agent     : ['A1', 'A1', 'A0', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A1', 'A1', 'A2', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A1', 'A2', 'A2', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A2', 'A1', 'A0', 'A0', 'A1', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A2', 'A2', 'A0', 'A1', 'A2', 'A0', 'A0', 'A1', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 46.110369360771784, min: 45.649265667164066, max: 46.5714730543795
# Current Dist (min)   : 45.696600000000004
# Current Walk (nodes) : [36242661, 4935936620, 8622281921, 450933176, 436368334, 2572086168, 2572086168]
# Number of nodes (#)  : 6
# Number of inodes (#) : 2
# % used inodes        : 0.12
# % inodes in walk     : 0.33
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915858, 451915971, 451915973, 451914977, 8560427115, 8560449918, 8534199881, 8534199896, 8534199887, 8534199909, 34564928, 4935936620, 34564928, 8534199909, 5128552424, 8534199871, 1592630249, 8534199865, 36508336, 295899971, 295899959, 36242667, 60056679, 36242662, 36242682, 36242679, 36242680, 8622275662, 8622275641, 8622275702, 8622281928, 8622281918, 8622281921, 8622281918, 8622281928, 8622275702, 8622275641, 8622275662, 8621999376, 8622275671, 8622275669, 8622275685, 8621999375, 8621999373, 450933176, 8621999373, 34564878, 436368333, 436368334, 436368333, 34564878, 10684421728, 10684421726, 10684421750, 36242679, 36242680, 8622275662, 8622275641, 8622275702, 8622281928, 8622281918, 8622281921, 8622281917, 8622275668, 800044371, 36242653, 36242654, 36242655, 2572086150, 2572086168, 2572086150, 36242655, 36242654, 36242653, 800044371, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 48
# Actions by agent     : ['A2', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A1', 'A1', 'A0', 'A1', 'A1', 'A0', 'A2', 'A0', 'A1', 'A1', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A2', 'A0', 'A0', 'A0', 'A2', 'A2']
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 201          |
# |    ep_rew_mean          | -152         |
# | time/                   |              |
# |    fps                  | 20           |
# |    iterations           | 3            |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0059476695 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.465        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.2         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00916     |
# |    value_loss           | 123          |
# ------------------------------------------
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 38.64235247897407, min: 38.25592895418433, max: 39.02877600376381
# Current Dist (min)   : 38.638451999999994
# Current Walk (nodes) : [36242661, 8534199866, 10684421749, 451915971, 2572086168, 8534199872]
# Number of nodes (#)  : 5
# Number of inodes (#) : 1
# % used inodes        : 0.06
# % inodes in walk     : 0.2
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915681, 451914645, 36508336, 8534199865, 8534199864, 8534199858, 8534199866, 8534199858, 8534199864, 8534199865, 36508336, 295899971, 295899959, 36242667, 60056679, 36242662, 36242682, 36242679, 10684421750, 10684421748, 10684421749, 10684421748, 10684421750, 36242679, 36242682, 36242662, 60056679, 36242667, 36242669, 36242668, 36508334, 451908623, 451915858, 451915971, 451915858, 451908623, 36508334, 450940987, 450940973, 34094859, 6328539753, 36242670, 36242658, 36242657, 180170248, 180168857, 81026594, 2572086168, 2572086150, 36242655, 36242654, 36242653, 800044371, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 17
# Actions by agent     : ['A2', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A1', 'A1', 'A0', 'A0', 'A1', 'A1', 'A2', 'A0', 'A1', 'A0', 'A1', 'A2', 'A2', 'A2', 'A0', 'A0', 'A1', 'A2', 'A2', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A1', 'A2', 'A1', 'A1', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A1', 'A2', 'A2', 'A0', 'A0', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A1']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 10.243190188998799, min: 10.140758287108811, max: 10.345622090888787
# Current Dist (min)   : 10.305000000000001
# Current Walk (nodes) : [36242661, 451908623, 36508336, 30349181, 451915971]
# Number of nodes (#)  : 4
# Number of inodes (#) : 3
# % used inodes        : 0.18
# % inodes in walk     : 0.75
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915681, 451914645, 36508336, 295899971, 36508234, 30349180, 5128548965, 5128548962, 30349181, 295899939, 60056679, 60056680, 36242661]
# reward: 10, total_reward: 64
# Actions by agent     : ['A2', 'A0', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A1', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A2', 'A2', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A0', 'A0', 'A1', 'A1', 'A1', 'A0', 'A0', 'A0', 'A1', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A2', 'A2', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A1', 'A0', 'A0', 'A1', 'A2', 'A1', 'A0', 'A0', 'A0', 'A1', 'A1', 'A0', 'A1', 'A2', 'A1', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A1', 'A1', 'A2', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A2', 'A1']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 9.282195254770485, min: 9.18937330222278, max: 9.37501720731819
# Current Dist (min)   : 9.262692
# Current Walk (nodes) : [36242661, 6328539741, 451914645, 8489963209]
# Number of nodes (#)  : 3
# Number of inodes (#) : 1
# % used inodes        : 0.06
# % inodes in walk     : 0.33
# Detailed route       : [36242661, 8573220359, 295900706, 6328539741, 295900706, 8573220359, 295900371, 36242669, 36242668, 36508334, 451908623, 451915681, 451914645, 451915681, 451908623, 36508334, 36242668, 36242669, 295900371, 36242661]
# reward: 10, total_reward: 3
# Actions by agent     : ['A1', 'A2', 'A2']
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 24          |
# |    iterations           | 4           |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018265173 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 122         |
# -----------------------------------------
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 15.946841404806644, min: 15.787372990758577, max: 16.10630981885471
# Current Dist (min)   : 15.852527999999998
# Current Walk (nodes) : [36242661]
# Number of nodes (#)  : 2
# Number of inodes (#) : 1
# % used inodes        : 0.06
# % inodes in walk     : 0.5
# Detailed route       : [36242661, 8573220359, 295900706, 6328539741, 36242659, 36242656, 36242657, 180170248, 180168857, 81026594, 180168857, 180170248, 36242657, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 2
# Actions by agent     : ['A2', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 21.17061661112731, min: 20.958910445016038, max: 21.382322777238585
# Current Dist (min)   : 21.186744
# Current Walk (nodes) : [36242661, 247277743, 451917438]
# Number of nodes (#)  : 2
# Number of inodes (#) : 0
# % used inodes        : 0.0
# % inodes in walk     : 0.0
# Detailed route       : [36242661, 60056680, 36242662, 36242682, 36242679, 10684421750, 10684421726, 10684421728, 34564878, 8621999373, 450933176, 30349183, 30349184, 2797280265, 2799356299, 34564871, 247277743, 34564871, 2799356299, 2797280265, 30349184, 30349183, 450933176, 8621999373, 34564878, 10684421728, 10684421726, 10684421750, 36242679, 36242682, 36242662, 60056680, 36242661]
# reward: 10, total_reward: 5
# Actions by agent     : ['A0', 'A2', 'A0', 'A1', 'A1']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 9.799392360508712, min: 9.701398436903625, max: 9.897386284113798
# Current Dist (min)   : 9.829367999999999
# Current Walk (nodes) : [36242661]
# Number of nodes (#)  : 2
# Number of inodes (#) : 1
# % used inodes        : 0.06
# % inodes in walk     : 0.5
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915681, 451914645, 36508336, 8534199865, 36508336, 451914645, 451915681, 451908623, 36508334, 36242668, 36242669, 295900371, 36242661]
# reward: 10, total_reward: 55
# Actions by agent     : ['A0', 'A1', 'A0', 'A1', 'A2', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A1', 'A2', 'A0', 'A1', 'A2', 'A0', 'A2', 'A2', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A2', 'A2', 'A2', 'A2', 'A0', 'A2', 'A2', 'A2', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A1', 'A2', 'A0', 'A0', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A0', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A0', 'A0', 'A0', 'A1', 'A1', 'A0', 'A1', 'A0', 'A1', 'A1', 'A2', 'A2', 'A1', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 17.19585699063004, min: 17.02389842072374, max: 17.367815560536343
# Current Dist (min)   : 17.038668000000005
# Current Walk (nodes) : [36242661, 2572086168]
# Number of nodes (#)  : 3
# Number of inodes (#) : 1
# % used inodes        : 0.06
# % inodes in walk     : 0.33
# Detailed route       : [36242661, 8573220359, 295900706, 6328539741, 36242659, 36242656, 800044371, 36242653, 36242654, 36242655, 2572086150, 2572086168, 81026594, 180168857, 34094932, 2572086187, 34094932, 180170248, 36242657, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 227
# Actions by agent     : ['A2', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A2', 'A1', 'A0', 'A1', 'A0', 'A0', 'A0', 'A1', 'A1', 'A2', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A1', 'A2', 'A0', 'A0', 'A1', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A2', 'A2', 'A0', 'A0', 'A0', 'A0', 'A1', 'A2', 'A0', 'A0', 'A1', 'A0', 'A1', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A1', 'A1', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A1', 'A1', 'A0', 'A1', 'A0', 'A0', 'A1', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A1', 'A1', 'A0', 'A0', 'A1', 'A0', 'A2', 'A2', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A1', 'A2', 'A2', 'A0', 'A0', 'A1', 'A2', 'A0', 'A0', 'A0', 'A0', 'A2', 'A1', 'A0', 'A2', 'A2', 'A0', 'A1', 'A1', 'A0', 'A0', 'A0', 'A0', 'A1', 'A2', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A1', 'A0', 'A2', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A1', 'A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A1', 'A0', 'A1', 'A0', 'A0', 'A2', 'A1', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A1', 'A2', 'A0', 'A0', 'A2', 'A1', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 48.717260442014094, min: 48.230087837593956, max: 49.20443304643423
# Current Dist (min)   : 48.531624
# Current Walk (nodes) : [36242661, 34564928, 30349181, 5206248518, 36242668, 451914645]
# Number of nodes (#)  : 7
# Number of inodes (#) : 4
# % used inodes        : 0.24
# % inodes in walk     : 0.57
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915858, 451915971, 451915973, 451914977, 8560427115, 8560449918, 8534199881, 8534199896, 8534199887, 8534199909, 34564928, 8534199909, 5128552424, 8534199871, 1592630249, 8534199865, 36508336, 295899971, 36508234, 30349180, 5128548965, 5128548962, 30349181, 295899939, 60056679, 60056680, 36242661, 8573220359, 295900706, 6328539741, 36242659, 36242658, 308580750, 81042780, 5206248644, 5206248663, 5206248621, 5206248519, 5206248518, 5206248519, 5206248621, 5206248663, 5206248644, 81042780, 308580750, 36242658, 36242670, 6328539753, 34094859, 450940973, 450940987, 36242668, 36508334, 451908623, 451915681, 451914645, 451915681, 451908623, 36508334, 450940987, 450940973, 34094859, 6328539753, 36242670, 36242658, 36242657, 180170248, 180168857, 81026594, 2572086168, 2572086150, 36242655, 36242654, 36242653, 800044371, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 166
# Actions by agent     : ['A2', 'A0', 'A0', 'A2', 'A1', 'A1', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A2', 'A0', 'A1', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A0', 'A1', 'A1', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A1', 'A1', 'A0', 'A2', 'A1', 'A1', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A2', 'A1', 'A0', 'A0', 'A0', 'A0', 'A0', 'A1', 'A1', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A2', 'A1', 'A2', 'A0', 'A0', 'A0', 'A1', 'A1', 'A0', 'A0', 'A1', 'A1', 'A0', 'A2', 'A2', 'A1', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A1', 'A2', 'A2', 'A0', 'A1', 'A2', 'A2', 'A2', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 37.47690916641849, min: 37.1021400747543, max: 37.85167825808267
# Current Dist (min)   : 37.805952000000005
# Current Walk (nodes) : [36242661, 34564928, 10684421750, 36242668, 295899939, 36242658]
# Number of nodes (#)  : 7
# Number of inodes (#) : 3
# % used inodes        : 0.18
# % inodes in walk     : 0.43
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915858, 451915971, 451915973, 451914977, 8560427115, 8560449918, 8534199881, 8534199896, 8534199887, 8534199909, 34564928, 8534199909, 5128552424, 8534199871, 1592630249, 8534199865, 36508336, 295899971, 295899959, 36242667, 60056679, 36242662, 36242682, 36242679, 10684421750, 36242679, 36242682, 36242662, 60056679, 36242667, 36242669, 36242668, 36242669, 36242667, 295899959, 295899939, 60056679, 60056680, 36242661, 8573220359, 295900706, 6328539741, 36242659, 36242658, 36242670, 6328539753, 34094859, 450940973, 450940987, 36508334, 451908623, 36508334, 36242668, 36242669, 295900371, 36242661]
# reward: 10, total_reward: 124
# Actions by agent     : ['A1', 'A0', 'A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A2', 'A1', 'A1', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A1', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A0', 'A1', 'A2', 'A0', 'A0', 'A2', 'A1', 'A0', 'A0', 'A1', 'A2', 'A2', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A1', 'A2', 'A2', 'A1', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A1', 'A2', 'A0', 'A0', 'A1', 'A1', 'A0', 'A2', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 32.42542218710359, min: 32.101167965232555, max: 32.74967640897463
# Current Dist (min)   : 32.514564
# Current Walk (nodes) : [36242661, 81026594, 8622275670]
# Number of nodes (#)  : 4
# Number of inodes (#) : 1
# % used inodes        : 0.06
# % inodes in walk     : 0.25
# Detailed route       : [36242661, 8573220359, 295900706, 6328539741, 36242659, 36242656, 36242657, 180170248, 180168857, 81026594, 2572086168, 2572086150, 36242655, 36242654, 36242653, 800044371, 8622275668, 8622281923, 8622281920, 8622275715, 8622281932, 8622275713, 8622275711, 8622275705, 8622275708, 8622275701, 8622275698, 8622275695, 8622275684, 8622275672, 8622275670, 8622275682, 8622275669, 8622275671, 8621999376, 8622275662, 36242680, 36242679, 36242682, 36242662, 60056679, 36242667, 36242669, 450940973, 34094868, 5221910727, 308580335, 295899149, 308580335, 5221910727, 34094868, 450940973, 36242669, 295900371, 36242661]
# reward: 10, total_reward: 87
# Actions by agent     : ['A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A2', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A1', 'A2', 'A1', 'A0', 'A0', 'A0', 'A1', 'A1', 'A1', 'A1', 'A0', 'A0', 'A2', 'A0', 'A0', 'A1', 'A2', 'A0', 'A1', 'A1', 'A1', 'A0', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A0', 'A1', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A1', 'A1', 'A0', 'A0', 'A1', 'A1', 'A0', 'A1', 'A2', 'A0', 'A0', 'A0', 'A0', 'A0', 'A2', 'A1', 'A1', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 15.623109088718426, min: 15.466877997831242, max: 15.77934017960561
# Current Dist (min)   : 15.703800000000001
# Current Walk (nodes) : [36242661]
# Number of nodes (#)  : 2
# Number of inodes (#) : 0
# % used inodes        : 0.0
# % inodes in walk     : 0.0
# Detailed route       : [36242661, 8573220359, 295900706, 6328539741, 36242659, 36242656, 800044371, 36242653, 36242654, 36242655, 2572086150, 36242655, 36242654, 36242653, 800044371, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 53
# Actions by agent     : ['A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A1', 'A0', 'A0', 'A1', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A1', 'A0', 'A2', 'A1', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 34.7277948695961, min: 34.38051692090014, max: 35.075072818292064
# Current Dist (min)   : 35.042711999999995
# Current Walk (nodes) : [36242661, 5206248686, 8621999373]
# Number of nodes (#)  : 4
# Number of inodes (#) : 0
# % used inodes        : 0.0
# % inodes in walk     : 0.0
# Detailed route       : [36242661, 8573220359, 295900706, 6328539741, 36242659, 36242658, 308580750, 81042780, 5206248643, 5206248641, 5206248686, 5206248641, 5206248643, 81042780, 308580750, 36242658, 36242659, 6328539741, 295900706, 8573220359, 36242661, 60056680, 36242662, 36242682, 36242679, 10684421750, 10684421726, 10684421728, 34564878, 8621999373, 34564878, 10684421728, 10684421726, 10684421750, 36242679, 36242682, 36242662, 60056680, 36242661, 8573220359, 295900706, 6328539741, 36242659, 36242658, 308580750, 36242671, 8821350205, 5206248858, 5206248871, 5206248857, 5206248871, 5206248858, 8821350205, 36242671, 308580750, 36242658, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 201
# Actions by agent     : ['A0', 'A1', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A1', 'A1', 'A1', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A1', 'A0', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A1', 'A2', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A1', 'A1', 'A2', 'A2', 'A2', 'A0', 'A0', 'A0', 'A1', 'A2', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A2', 'A1', 'A1', 'A2', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A0', 'A2', 'A1', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A0', 'A0', 'A1', 'A2', 'A1', 'A0', 'A0', 'A0', 'A0', 'A1', 'A2', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A1', 'A1', 'A0', 'A0', 'A1', 'A0', 'A1', 'A2', 'A1', 'A1', 'A2', 'A0', 'A0', 'A1', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A1', 'A1', 'A2', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A0', 'A1', 'A1', 'A2', 'A0', 'A2', 'A1', 'A1', 'A0', 'A0', 'A0', 'A1', 'A1', 'A0', 'A0', 'A1', 'A0']
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 188         |
# |    ep_rew_mean          | -46.5       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 5           |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016077718 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0275     |
# |    value_loss           | 179         |
# -----------------------------------------
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 41.573370561543406, min: 41.15763685592797, max: 41.989104267158844
# Current Dist (min)   : 41.584812
# Current Walk (nodes) : [36242661, 5206248638, 5206248638, 8534199865, 8706816411]
# Number of nodes (#)  : 6
# Number of inodes (#) : 2
# % used inodes        : 0.12
# % inodes in walk     : 0.33
# Detailed route       : [36242661, 8573220359, 295900706, 6328539741, 36242659, 36242658, 308580750, 81042780, 5206248644, 5206248668, 5206248638, 5206248668, 5206248644, 81042780, 308580750, 36242658, 36242670, 6328539753, 34094859, 450940973, 450940987, 36508334, 451908623, 451915681, 451914645, 36508336, 8534199865, 1592630249, 8534199871, 5128552424, 8534199909, 34564928, 4935936620, 5128551738, 8706816413, 8706816414, 8706816411, 8706816414, 8706816413, 5128551738, 4935936620, 34564928, 8534199909, 8534199887, 8534199896, 8534199881, 8560449918, 8560427115, 451914977, 451915973, 451915971, 451915858, 451908623, 36508334, 450940987, 450940973, 34094859, 6328539753, 36242670, 36242658, 36242657, 180170248, 180168857, 81026594, 180168857, 180170248, 36242657, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 11
# Actions by agent     : ['A2', 'A0', 'A0', 'A1', 'A1', 'A2', 'A1', 'A2', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 26.15051831614482, min: 25.88901313298337, max: 26.41202349930627
# Current Dist (min)   : 26.10456
# Current Walk (nodes) : [36242661, 8534199878]
# Number of nodes (#)  : 3
# Number of inodes (#) : 1
# % used inodes        : 0.06
# % inodes in walk     : 0.33
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915858, 451915971, 451915973, 451914977, 8560427115, 8560449918, 8534199881, 8534199878, 8534199881, 8560449918, 8560427115, 451914977, 451915973, 451915971, 451915858, 451908623, 36508334, 450940987, 450940973, 34094859, 6328539753, 36242670, 36242658, 36242657, 180170248, 180168857, 81026594, 2572086168, 2572086150, 36242655, 36242654, 36242653, 800044371, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 9
# Actions by agent     : ['A0', 'A2', 'A0', 'A0', 'A0', 'A1', 'A2', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 43.24389766462127, min: 42.81145868797506, max: 43.67633664126748
# Current Dist (min)   : 42.82461599999999
# Current Walk (nodes) : [36242661, 8489963209, 5801761936, 8621999375, 8489963209]
# Number of nodes (#)  : 4
# Number of inodes (#) : 1
# % used inodes        : 0.06
# % inodes in walk     : 0.25
# Detailed route       : [36242661, 60056680, 36242662, 36242682, 36242679, 10684421750, 10684421726, 10684421728, 34564878, 8621999373, 450933176, 30349183, 30349184, 8489995739, 8489995729, 8489963212, 8489963209, 8489963212, 8489995729, 8489995739, 30349184, 30349183, 450933176, 8621999373, 34564878, 436368333, 436368334, 30349181, 5128548962, 5128548965, 30349180, 36508234, 295899971, 36508336, 451914645, 451914987, 451915971, 451916271, 451917250, 451917249, 7520932877, 295899723, 5206243901, 5206248876, 5801761936, 5206248876, 5206243901, 295899723, 7520932877, 451917249, 451917250, 451916271, 451915971, 451914987, 451914645, 36508336, 295899971, 36508234, 30349180, 5128548965, 5128548962, 30349181, 436368334, 436368333, 34564878, 8621999373, 8621999375, 8622275685, 8622275669, 8622275671, 8621999376, 8622275662, 36242680, 36242679, 36242682, 36242662, 60056680, 36242661]
# reward: 10, total_reward: 269
# Actions by agent     : ['A1', 'A0', 'A1', 'A0', 'A0', 'A2', 'A1', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A1', 'A0', 'A2', 'A0', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A1', 'A2', 'A0', 'A2', 'A1', 'A2', 'A0', 'A1', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A2', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A1', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A1', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A0', 'A0', 'A0', 'A1', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A0', 'A1', 'A2', 'A0', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A1', 'A2', 'A0', 'A0', 'A1', 'A2', 'A2', 'A1', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A2', 'A2', 'A1', 'A0', 'A1', 'A1', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A1', 'A1', 'A0', 'A0', 'A0', 'A0', 'A0', 'A1', 'A2', 'A0', 'A1', 'A1', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A1', 'A1', 'A2', 'A0', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A1', 'A2', 'A0', 'A0', 'A2', 'A1', 'A2', 'A0', 'A0', 'A1', 'A1', 'A2']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 24.525332307210704, min: 24.280078984138598, max: 24.77058563028281
# Current Dist (min)   : 24.667752000000004
# Current Walk (nodes) : [36242661, 8706816414]
# Number of nodes (#)  : 3
# Number of inodes (#) : 0
# % used inodes        : 0.0
# % inodes in walk     : 0.0
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915858, 451915971, 451915973, 451914977, 8560427115, 8560449918, 8534199881, 8534199896, 8534199887, 8534199909, 34564928, 4935936620, 5128551738, 8706816413, 8706816414, 8706816413, 5128551738, 4935936620, 34564928, 8534199909, 8534199887, 8534199896, 8534199881, 8560449918, 8560427115, 451914977, 451915973, 451915971, 451915858, 451908623, 36508334, 450940987, 450940973, 34094859, 6328539753, 36242670, 36242658, 308580750, 81042780, 5206248644, 5206248668, 5206248644, 81042780, 308580750, 36242658, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 148
# Actions by agent     : ['A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A1', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A2', 'A0', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A0', 'A2', 'A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A1', 'A1', 'A0', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A1', 'A1', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A2', 'A1', 'A0', 'A0', 'A0', 'A1', 'A1', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 18.3386113043861, min: 18.155225191342236, max: 18.52199741742996
# Current Dist (min)   : 18.198672000000002
# Current Walk (nodes) : [36242661]
# Number of nodes (#)  : 2
# Number of inodes (#) : 0
# % used inodes        : 0.0
# % inodes in walk     : 0.0
# Detailed route       : [36242661, 60056680, 36242662, 36242682, 36242679, 10684421750, 10684421726, 10684421728, 34564878, 8621999373, 450933176, 30349183, 30349184, 8489995739, 8489995729, 8489963214, 8489995729, 8489995739, 30349184, 30349183, 450933176, 8621999373, 34564878, 10684421728, 10684421726, 10684421750, 36242679, 36242682, 36242662, 60056680, 36242661]
# reward: 10, total_reward: 239
# Actions by agent     : ['A1', 'A1', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A1', 'A2', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A2', 'A2', 'A2', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A1', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A2', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A2', 'A0', 'A1', 'A0', 'A1', 'A2', 'A0', 'A0', 'A1', 'A2', 'A1', 'A0', 'A2', 'A0', 'A0', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A2', 'A1', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A2', 'A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A0', 'A2', 'A2', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A2', 'A1', 'A0', 'A0', 'A1', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 43.011232260099725, min: 42.58111993749873, max: 43.44134458270072
# Current Dist (min)   : 43.030103999999994
# Current Walk (nodes) : [451915681, 8706816414, 295899939, 5206248859, 8489963214, 36242680]
# Number of nodes (#)  : 5
# Number of inodes (#) : 2
# % used inodes        : 0.12
# % inodes in walk     : 0.4
# Detailed route       : [451915681, 451914645, 451914987, 451914977, 8560427115, 8560449918, 8534199881, 8534199896, 8534199887, 8534199909, 34564928, 4935936620, 5128551738, 8706816413, 8706816414, 8706816413, 5128551738, 4935936620, 34564928, 8534199909, 5128552424, 8534199871, 1592630249, 8534199865, 36508336, 295899971, 36508234, 30349180, 5128548965, 5128548962, 30349181, 295899939, 295899959, 36242667, 36242669, 34094859, 6328539753, 36242670, 36242671, 8821350205, 5206248859, 8821350205, 36242671, 308580750, 36242658, 36242659, 6328539741, 295900706, 8573220359, 36242661, 60056680, 36242662, 36242682, 36242679, 10684421750, 10684421726, 10684421728, 34564878, 8621999373, 450933176, 30349183, 30349184, 8489995739, 8489995729, 8489963214, 8489995729, 8489995739, 30349184, 30349183, 450933176, 8621999373, 34564878, 436368333, 436368334, 30349181, 5128548962, 5128548965, 30349180, 36508234, 295899971, 36508336, 451914645, 451915681]
# reward: 10, total_reward: 65
# Actions by agent     : ['A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A1', 'A0', 'A2', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A2', 'A0', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A2', 'A0', 'A1', 'A0', 'A2', 'A1', 'A1', 'A2', 'A0', 'A0', 'A1', 'A1']
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | -3.33       |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 6           |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015698936 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.887      |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 124         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 192         |
# |    ep_rew_mean          | 30.1        |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 7           |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015475296 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | 0.347       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.7        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00963    |
# |    value_loss           | 121         |
# -----------------------------------------
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 26.23515250064343, min: 25.972800975636996, max: 26.497504025649864
# Current Dist (min)   : 26.339844000000003
# Current Walk (nodes) : [36242661, 8622281919]
# Number of nodes (#)  : 3
# Number of inodes (#) : 0
# % used inodes        : 0.0
# % inodes in walk     : 0.0
# Detailed route       : [36242661, 60056680, 36242662, 36242682, 36242679, 36242680, 8622275662, 8621999376, 8622275657, 8622275691, 8622275692, 8622275696, 8622275699, 8622275706, 8622275703, 8622275709, 8622275712, 8622281929, 8622275714, 8622275693, 8622281919, 8622281922, 8622281923, 8622275668, 800044371, 36242656, 36242659, 36242658, 308580750, 36242671, 5206248474, 8821350203, 8821395822, 5206248484, 8821350200, 8821350198, 8821350199, 6359910833, 8821350199, 8821350198, 8821350200, 5206248484, 8821395822, 8821350203, 5206248474, 36242671, 308580750, 36242658, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 296
# Actions by agent     : ['A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A2', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A2', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A0', 'A1', 'A2', 'A0', 'A1', 'A0', 'A0', 'A0', 'A2', 'A2', 'A1', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A1', 'A2', 'A0', 'A0', 'A1', 'A0', 'A2', 'A2', 'A1', 'A0', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A1', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A2', 'A1', 'A0', 'A1', 'A1', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A2', 'A1', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A1', 'A1', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A0', 'A1', 'A1', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 11.419050536085816, min: 11.304860030724958, max: 11.533241041446674
# Current Dist (min)   : 11.482536
# Current Walk (nodes) : [36242661]
# Number of nodes (#)  : 2
# Number of inodes (#) : 0
# % used inodes        : 0.0
# % inodes in walk     : 0.0
# Detailed route       : [36242661, 8573220359, 295900706, 6328539741, 36242659, 36242658, 308580750, 81042780, 5206248644, 5206248668, 5206248637, 5206248635, 5206248637, 5206248668, 5206248644, 81042780, 308580750, 36242658, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 63
# Actions by agent     : ['A1', 'A0', 'A1', 'A0', 'A2', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A0', 'A1', 'A0', 'A2', 'A0', 'A1', 'A0', 'A1', 'A0', 'A2', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A0', 'A1', 'A0', 'A1', 'A0', 'A0', 'A1', 'A1', 'A0', 'A0', 'A2', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A1', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A1', 'A0', 'A2', 'A0', 'A1', 'A1', 'A0', 'A0', 'A2', 'A0', 'A0', 'A1', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 6.34277410348562, min: 6.279346362450764, max: 6.406201844520477
# Current Dist (min)   : 6.395087999999999
# Current Walk (nodes) : [36242661]
# Number of nodes (#)  : 2
# Number of inodes (#) : 1
# % used inodes        : 0.06
# % inodes in walk     : 0.5
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915681, 451908623, 36508334, 36242668, 36242669, 295900371, 36242661]
# reward: 10, total_reward: 92
# ...
# Current Walk (nodes) : [36242661, 36242668, 36242668]
# Number of nodes (#)  : 4
# Number of inodes (#) : 2
# % used inodes        : 0.12
# % inodes in walk     : 0.5
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 450940987, 450940973, 34094859, 6328539753, 36242670, 36242658, 36242657, 180170248, 180168857, 81026594, 2572086168, 2572086150, 36242655, 36242654, 36242653, 800044371, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 323
# Actions by agent     : ['A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A2', 'A0', 'A1', 'A2', 'A0', 'A0', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A1', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A1', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 10.007766644241382, min: 9.907688977798967, max: 10.107844310683797
# Current Dist (min)   : 9.913188
# Current Walk (nodes) : [36242661, 450940987]
# Number of nodes (#)  : 3
# Number of inodes (#) : 2
# % used inodes        : 0.12
# % inodes in walk     : 0.67
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 450940987, 36508334, 451908623, 451915681, 451914645, 36508336, 8534199865, 36508336, 451914645, 451915681, 451908623, 36508334, 36242668, 36242669, 295900371, 36242661]
# reward: 10, total_reward: 82
# Actions by agent     : ['A2', 'A2', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 21.27507193284081, min: 21.0623212135124, max: 21.487822652169218
# Current Dist (min)   : 21.463007999999995
# Current Walk (nodes) : [36242661, 36242668, 451915858]
# Number of nodes (#)  : 4
# Number of inodes (#) : 3
# % used inodes        : 0.18
# % inodes in walk     : 0.75
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915858, 451908623, 36508334, 450940987, 450940973, 34094859, 6328539753, 36242670, 36242658, 36242657, 180170248, 180168857, 81026594, 180168857, 180170248, 36242657, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 91
# Actions by agent     : ['A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0']
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 209          |
# |    ep_rew_mean          | 368          |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 26           |
# |    time_elapsed         | 469          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0027720584 |
# |    clip_fraction        | 0.0756       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.44        |
# |    explained_variance   | 0.304        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 71.8         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 323          |
# ------------------------------------------
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 10.35911609743421, min: 10.255524936459867, max: 10.462707258408553
# Current Dist (min)   : 10.369596
# Current Walk (nodes) : [36242661, 451915858]
# Number of nodes (#)  : 3
# Number of inodes (#) : 2
# % used inodes        : 0.12
# % inodes in walk     : 0.67
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915858, 451914645, 36508336, 295899971, 36508234, 30349180, 5128548965, 5128548962, 30349181, 295899939, 60056679, 60056680, 36242661]
# reward: 10, total_reward: 186
# Actions by agent     : ['A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A2', 'A0', 'A1', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A1', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0']
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 209         |
# |    ep_rew_mean          | 373         |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 27          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009976909 |
# |    clip_fraction        | 0.0595      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.439      |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.4        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 225         |
# -----------------------------------------
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 11.12662953025978, min: 11.015363234957183, max: 11.237895825562378
# Current Dist (min)   : 11.058048000000001
# Current Walk (nodes) : [36242661, 5128521073]
# Number of nodes (#)  : 3
# Number of inodes (#) : 2
# % used inodes        : 0.12
# % inodes in walk     : 0.67
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 5128521073, 36508334, 36242668, 36242669, 36242667, 295899959, 295899939, 30349181, 295899939, 60056679, 60056680, 36242661]
# reward: 10, total_reward: 356
# Actions by agent     : ['A1', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A1', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A1', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A1', 'A0', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A2', 'A0', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0']
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 211          |
# |    ep_rew_mean          | 376          |
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 28           |
# |    time_elapsed         | 476          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0056221173 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.432       |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000946    |
# |    value_loss           | 77.7         |
# ------------------------------------------
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 15.753247471925373, min: 15.59571499720612, max: 15.910779946644627
# Current Dist (min)   : 15.852527999999998
# Current Walk (nodes) : [36242661]
# Number of nodes (#)  : 2
# Number of inodes (#) : 1
# % used inodes        : 0.06
# % inodes in walk     : 0.5
# Detailed route       : [36242661, 8573220359, 295900706, 6328539741, 36242659, 36242656, 36242657, 180170248, 180168857, 81026594, 180168857, 180170248, 36242657, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 238
# Actions by agent     : ['A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 11.694093199207835, min: 11.577152267215757, max: 11.811034131199913
# Current Dist (min)   : 11.607660000000001
# Current Walk (nodes) : [36242661, 451915858, 451915681]
# Number of nodes (#)  : 4
# Number of inodes (#) : 3
# % used inodes        : 0.18
# % inodes in walk     : 0.75
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915858, 451915681, 451914645, 36508336, 295899971, 36508234, 30349180, 5128548965, 5128548962, 30349181, 436368334, 30349181, 295899939, 60056679, 60056680, 36242661]
# reward: 10, total_reward: 90
# Actions by agent     : ['A2', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A2', 'A0']
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 210          |
# |    ep_rew_mean          | 381          |
# | time/                   |              |
# |    fps                  | 123          |
# |    iterations           | 29           |
# |    time_elapsed         | 480          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0022621143 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.431       |
# |    explained_variance   | 0.713        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.9         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000724    |
# |    value_loss           | 85.3         |
# ------------------------------------------
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 24.058708454463357, min: 23.818121369918725, max: 24.29929553900799
# Current Dist (min)   : 23.967984
# Current Walk (nodes) : [36242661, 451908623, 36508336]
# Number of nodes (#)  : 4
# Number of inodes (#) : 3
# % used inodes        : 0.18
# % inodes in walk     : 0.75
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 451908623, 451915681, 451914645, 36508336, 451914645, 451915681, 451908623, 36508334, 450940987, 450940973, 34094859, 6328539753, 36242670, 36242658, 36242657, 180170248, 180168857, 81026594, 180168857, 180170248, 36242657, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 80
# Actions by agent     : ['A2', 'A0', 'A2', 'A2', 'A1', 'A0', 'A2', 'A2', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A0', 'A0', 'A2', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A2', 'A0', 'A2', 'A0', 'A0', 'A0', 'A2', 'A0', 'A2', 'A2', 'A0', 'A0', 'A2', 'A2', 'A0']
# ************************ NEW WALK MADE! **************************************************
# Desired Dist (min)   : 30.02468346760277, min: 29.724436632926743, max: 30.324930302278798
# Current Dist (min)   : 30.094776
# Current Walk (nodes) : [36242661, 5128521073, 5128521073, 30349181, 5128521073]
# Number of nodes (#)  : 6
# Number of inodes (#) : 3
# % used inodes        : 0.18
# % inodes in walk     : 0.5
# Detailed route       : [36242661, 295900371, 36242669, 36242668, 36508334, 5128521073, 36508334, 36242668, 36242669, 36242667, 295899959, 295899939, 30349181, 295899939, 295899959, 36242667, 36242669, 36242668, 36508334, 5128521073, 36508334, 450940987, 450940973, 34094859, 6328539753, 36242670, 36242658, 36242657, 180170248, 180168857, 81026594, 180168857, 180170248, 36242657, 36242656, 36242659, 6328539741, 295900706, 8573220359, 36242661]
# reward: 10, total_reward: 10
# Actions by agent     : ['A2', 'A2', 'A2', 'A2', 'A2', 'A0']
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 213          |
# |    ep_rew_mean          | 387          |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 30           |
# |    time_elapsed         | 484          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0029960615 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.467       |
# |    explained_variance   | 0.387        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 123          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 140          |
# ------------------------------------------

# %%
# save model and close env

agent.save("WalksPPO")
env.close()

# %%
# End
